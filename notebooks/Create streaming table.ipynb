# %% [markdown]
# # Create Streaming Table (SDP)

# %%
# %sql
-- Use SQL WH compute
-- SDP is created successfully
CREATE OR REFRESH STREAMING TABLE dbacademy.labuser15129932_1780689028.sales_streaming_2 AS
SELECT *
FROM STREAM read_files(
    '/Volumes/dbacademy_ecommerce/v01/raw/sales-csv',
    format => 'csv', -- this doesn't have any effect
    delimiter => '|' -- necessary for right column/type definition
)

# %%
# Use Classic
# SQL WH doesn't allow to run Python code
# No table is created here. This code should run inside a SDP
from pyspark import pipelines as dp

@dp.table
def sales_bronze():
  return (
    spark.readStream.format("cloudFiles")
    .option("cloudFiles.format", "csv")
    .option("cloudFiles.inferColumnTypes", "true")
    .load("/Volumes/dbacademy_ecommerce/v01/raw/sales-csv")
  )
