# %% [markdown]
# # Create Streaming Table

# %%
# %sql
CREATE OR REFRESH STREAMING TABLE dbacademy.labuser15129932_1780689028.car_streaming AS
SELECT *
FROM STREAM read_files(
    '/Volumes/dbacademy_ecommerce/v01/raw/sales-csv',
    format => 'csv'
)
