# %%
# %sql
DESCRIBE TABLE EXTENDED certification.default.breast_cancer_ok;

# %%
#param_task = dbutils.widgets.get("task_param")
#display(param_task)

# %%
#task_param = dbutils.widgets.get("job_param")
#print("JOB PARAM")
#print(task_param)

# %%
#dbutils.widgets.text("usuario_nombre", "", "Nombre del usuario")
#nombre = dbutils.widgets.get("usuario_nombre")

# %%
#print(nombre)

# %%
# %sql
select * from certification.default.breast_cancer_ok

# %%
#import time
#time.sleep(60)

# %%
print("DONE!")
